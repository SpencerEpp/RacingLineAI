# %%
from data_manager import create_inference_data

# %%
track = create_inference_data("./data/amogus.png")

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,6))
plt.imshow(track["track_image"], cmap='grey')
plt.plot(track["center"][:, 0], track["center"][:, 1], 'r-', label="Centerline")
plt.legend()
#plt.axis(False)
plt.show()

# %%
import numpy as np

# %%
indices = np.random.choice(len(track["patches"]), 4, replace=False)
sampled = track["patches"][indices]
cent_point = track["center"][indices]

fix, axes = plt.subplots(1, 4, figsize=(10,10))
axes = axes.flatten()

for i in range (4):
    axes[i].imshow(sampled[i], cmap='gray')
    axes[i].axis('off')

plt.tight_layout()
plt.show()
